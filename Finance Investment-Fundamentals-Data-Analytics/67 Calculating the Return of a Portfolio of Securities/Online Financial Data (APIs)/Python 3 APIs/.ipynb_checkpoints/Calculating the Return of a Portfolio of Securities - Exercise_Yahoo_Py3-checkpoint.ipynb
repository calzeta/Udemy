# %% [markdown]
# ## Calculating the Return of a Portfolio of Securities

# %% [markdown]
# Download data for a portfolio composed of 5 stocks. Do it for British Petroleum, Ford, Exxon, Lincoln, and Apple for the period ‘2000-1-1’ until today.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['BP', 'F', 'XOM', 'LNC', 'AAPL']
mydata = pd.DataFrame()
for t in tickers:
    mydata[t] = wb.DataReader(t, data_source='yahoo', start='2000-1-1')['Adj Close']

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5044 entries, 2000-01-03 to 2020-01-21
# Data columns (total 5 columns):
# BP      5044 non-null float64
# F       5044 non-null float64
# XOM     5044 non-null float64
# LNC     5044 non-null float64
# AAPL    5044 non-null float64
# dtypes: float64(5)
# memory usage: 236.4 KB

# %% [markdown]
# ### Normalization to 100:
#
# $$
# \frac {P_t}{P_0} * 100
# $$

# %% [markdown]
# Normalize to a hundred and plot the data on a graph (you can apply the .loc() or the .iloc() method).

# %%
mydata.iloc[0]
# Out:
# BP      24.050200
# F       15.585759
# XOM     21.858601
# LNC     24.672104
# AAPL     3.478462
# Name: 2000-01-03 00:00:00, dtype: float64

# %%
(mydata / mydata.iloc[0] * 100).plot(figsize = (15, 6));
plt.show()

# %% [markdown]
# How would you interpret the behavior of the stocks? Just by looking at the chart, would you be able to create a portfolio that provides a solid return on investment?

# %% [markdown]
# *****

# %% [markdown]
# ### Calculating the Return of a Portfolio of Securities

# %% [markdown]
# Obtain the simple return of the securities in the portfolio and store the results in a new table.

# %%
returns = (mydata / mydata.shift(1)) - 1
returns.head()
# Out:
#                   BP         F       XOM       LNC      AAPL
# Date
# 2000-01-03       NaN       NaN       NaN       NaN       NaN
# 2000-01-04 -0.005313 -0.033413 -0.019154 -0.028800 -0.084311
# 2000-01-05  0.034188  0.003704  0.054516 -0.034596  0.014634
# 2000-01-06  0.002066  0.001231  0.051697  0.018302 -0.086538
# 2000-01-07 -0.018557  0.073709 -0.002934  0.025338  0.047368

# %% [markdown]
# First, assume you would like to create an equally-weighted portfolio. Create the array, naming it “weights”.

# %%
weights = np.array([0.20, 0.20, 0.20, 0.20, 0.20])

# %% [markdown]
# Obtain the annual returns of each of the stocks and then calculate the dot product of these returns and the weights.

# %%
annual_returns = returns.mean() * 250
annual_returns
# Out:
# BP      0.060703
# F       0.058181
# XOM     0.084182
# LNC     0.172897
# AAPL    0.308025
# dtype: float64

# %%
np.dot(annual_returns, weights)
# Out:
# 0.13679782873308086

# %% [markdown]
# Transform the result into a percentage form.

# %%
pfolio_1 = str(round(np.dot(annual_returns, weights), 5) * 100) + ' %'
print (pfolio_1)
# Out:
# 13.68 %

# %%
weights_2 = np.array([0.05, 0.05, 0.10, 0.30, 0.50])
pfolio_2 = str(round(np.dot(annual_returns, weights_2), 5) * 100) + ' %'
print (pfolio_2)
# Out:
# 22.024 %

# %% [markdown]
# Is the return of this portfolio satisfactory?
